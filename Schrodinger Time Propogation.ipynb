# %%
# Schrodinger Time Propogation

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
# inital setup

n_x = 100

alpha = 1
k = 0.1
x_0 = 0

x = np.linspace(-5, 5, n_x)
psi = np.empty([n_x,1]).astype(complex)

for i in range(0, n_x):
    psi[i] = np.exp(-alpha * (x[i] - x_0)**2 + 1j * k * x[i])

#plt.plot(x, psi_real, label="real")
#plt.plot(x, psi_imag, label="imaginary")
plt.plot(x, psi.real, label="real")
plt.plot(x, psi.imag, label="imaginary")
plt.legend()
plt.title("initial psi")
plt.xlabel("x")
plt.ylabel("psi")
plt.show()

# time propogation

H = 1
dt = 0.01
n_t = 100

for j in range(0, n_t):
    for i in range(0, n_x):
        psi[i] = (1 + (-1j*H*dt)) * psi[i]

    if (j % 30 == 0):
        plt.plot(x, psi.real, label=("real t="+str((j*dt))))
        plt.plot(x, psi.imag, label=("imag t="+str((j*dt))))

plt.legend()
plt.title("time propogated psi")
plt.xlabel("x")
plt.ylabel("psi")
plt.show()

# %%
prob_psi = np.zeros(n_x)

for i in range(0, n_x):
    prob_psi[i] = ((psi[i].real + psi[i].imag) * (psi[i].real - psi[i].imag)).real

plt.plot(x, psi**2)
# Out:
# C:\Users\tillm\AppData\Local\Temp\ipykernel_6976\131017930.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   prob_psi[i] = ((psi[i].real + psi[i].imag) * (psi[i].real - psi[i].imag)).real
